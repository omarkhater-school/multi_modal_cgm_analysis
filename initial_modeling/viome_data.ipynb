# %%
import pandas as pd
import ast
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def read_viome_data(path):
    viome_data = pd.read_csv(path)
    viome_data['Viome'] = viome_data['Viome'].apply(ast.literal_eval).apply(np.array)
    return viome_data

def read_labels(path):
    labels = pd.read_csv(path)
    return labels

# %%
label_train = pd.read_csv("../data/label_train.csv")
label_test = pd.read_csv("../data/label_test_breakfast_only.csv")

viome_train = read_viome_data('../data/demo_viome_train.csv')
viome_test = read_viome_data('../data/demo_viome_test.csv')

# %%
viome_train.head()
# Out:
#    Subject ID  Age  Gender  Weight  Height             Race  Diabetes Status  \
# 0           1   27       0   133.8   65.00  Hispanic/Latino                1
# 1           2   49       1   169.2   62.00  Hispanic/Latino                1
# 2           3   59       1   157.0   64.00  Hispanic/Latino                3
# 3           5   51       1   172.0   62.50  Hispanic/Latino                3
# 4           6   51       1   197.0   68.75            White                1
#
#    A1C  Baseline Fasting Glucose  Insulin  Triglycerides  Cholesterol   HDL  \
# 0  5.4                      91.0      2.5           67.0        216.0  74.0
# 1  5.5                      93.0     14.8           61.0        181.0  91.0
# 2  6.5                     118.0     17.4          154.0        190.0  74.0
# 3  6.6                     144.0     12.9          392.0        269.0  38.0
# 4  5.2                      96.0      6.4           75.0        203.0  72.0
#
#    Non-HDL    LDL  VLDL  CHO/HDL Ratio   HOMA-IR        BMI  \
# 0    142.0  130.0  13.0            2.9  0.561728  22.263053
# 1     90.0   78.0  12.0            2.0  3.398519  30.943704
# 2    116.0   90.0  31.0            2.6  5.069630  26.946045
# 3    231.0  157.0  78.0            7.1  4.586667  30.954496
# 4    131.0  118.0  15.0            2.8  1.517037  29.300575
#
#                                                Viome
# 0  [-11.691621427726268, -7.744787588227839, -7.6...
# 1  [-9.395216776716872, -7.315438412832852, 1.103...
# 2  [-11.007947281293239, -8.444134921199856, 0.28...
# 3  [-6.21833166351615, -5.868646092839025, -6.612...
# 4  [-6.7953636871125, -6.50799421035929, -1.85678...

# %%
demograph_train_df = viome_train.drop(columns = ["Viome"], axis = 1)
demograph_train_df.head()
# Out:
#    Subject ID  Age  Gender  Weight  Height             Race  Diabetes Status  \
# 0           1   27       0   133.8   65.00  Hispanic/Latino                1
# 1           2   49       1   169.2   62.00  Hispanic/Latino                1
# 2           3   59       1   157.0   64.00  Hispanic/Latino                3
# 3           5   51       1   172.0   62.50  Hispanic/Latino                3
# 4           6   51       1   197.0   68.75            White                1
#
#    A1C  Baseline Fasting Glucose  Insulin  Triglycerides  Cholesterol   HDL  \
# 0  5.4                      91.0      2.5           67.0        216.0  74.0
# 1  5.5                      93.0     14.8           61.0        181.0  91.0
# 2  6.5                     118.0     17.4          154.0        190.0  74.0
# 3  6.6                     144.0     12.9          392.0        269.0  38.0
# 4  5.2                      96.0      6.4           75.0        203.0  72.0
#
#    Non-HDL    LDL  VLDL  CHO/HDL Ratio   HOMA-IR        BMI
# 0    142.0  130.0  13.0            2.9  0.561728  22.263053
# 1     90.0   78.0  12.0            2.0  3.398519  30.943704
# 2    116.0   90.0  31.0            2.6  5.069630  26.946045
# 3    231.0  157.0  78.0            7.1  4.586667  30.954496
# 4    131.0  118.0  15.0            2.8  1.517037  29.300575

# %%
demograph_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject ID                36 non-null     int64
#  1   Age                       36 non-null     int64
#  2   Gender                    36 non-null     int64
#  3   Weight                    36 non-null     float64
#  4   Height                    36 non-null     float64
#  5   Race                      36 non-null     object
#  6   Diabetes Status           36 non-null     int64
#  7   A1C                       36 non-null     float64
#  8   Baseline Fasting Glucose  36 non-null     float64
#  9   Insulin                   36 non-null     float64
#  10  Triglycerides             36 non-null     float64
#  11  Cholesterol               36 non-null     float64
#  12  HDL                       36 non-null     float64
#  13  Non-HDL                   36 non-null     float64
#  14  LDL                       36 non-null     float64
#  15  VLDL                      36 non-null     float64
#  16  CHO/HDL Ratio             36 non-null     float64
#  17  HOMA-IR                   36 non-null     float64
#  18  BMI                       36 non-null     float64
# dtypes: float64(14), int64(4), object(1)
# memory usage: 5.5+ KB

# %%
demograph_train_df.nunique()
# Out:
# Subject ID                  36
# Age                         24
# Gender                       2
# Weight                      35
# Height                      16
# Race                         3
# Diabetes Status              3
# A1C                         24
# Baseline Fasting Glucose    32
# Insulin                     32
# Triglycerides               33
# Cholesterol                 34
# HDL                         26
# Non-HDL                     33
# LDL                         31
# VLDL                        21
# CHO/HDL Ratio               29
# HOMA-IR                     36
# BMI                         36
# dtype: int64

# %%
expanded_df = pd.DataFrame(
    viome_train['Viome'].to_list(), 
    columns=[f'Viome_{i}' for i in range(len(viome_train['Viome'][0]))])

# Combine with the original DataFrame (if needed)
df = pd.concat([demograph_train_df, expanded_df], axis=1)

# %%
df.head()
# Out:
#    Subject ID  Age  Gender  Weight  Height             Race  Diabetes Status  \
# 0           1   27       0   133.8   65.00  Hispanic/Latino                1
# 1           2   49       1   169.2   62.00  Hispanic/Latino                1
# 2           3   59       1   157.0   64.00  Hispanic/Latino                3
# 3           5   51       1   172.0   62.50  Hispanic/Latino                3
# 4           6   51       1   197.0   68.75            White                1
#
#    A1C  Baseline Fasting Glucose  Insulin  ...  Viome_17  Viome_18  Viome_19  \
# 0  5.4                      91.0      2.5  ...  1.183266  0.123951  1.422716
# 1  5.5                      93.0     14.8  ...  0.348451  1.591451  0.748944
# 2  6.5                     118.0     17.4  ... -0.202068 -1.578614 -1.356888
# 3  6.6                     144.0     12.9  ... -3.206188 -1.994911  1.867685
# 4  5.2                      96.0      6.4  ...  0.738694  2.938831 -2.335281
#
#    Viome_20  Viome_21  Viome_22  Viome_23  Viome_24  Viome_25  Viome_26
# 0 -0.201777  0.773843 -0.125457 -0.352396 -0.241578 -0.135894 -0.164389
# 1 -0.017463  0.514344 -0.392209 -0.211173 -0.210122 -0.007723 -0.090217
# 2  0.143230 -1.742321  0.451295  0.304562 -0.049945  0.188032 -0.039500
# 3 -1.029219 -0.412351 -0.657447  0.115855  0.093384  0.104649  0.009800
# 4  0.162024 -0.439828  0.176664  0.474702  0.034012  0.210099  0.338655
#
# [5 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject ID                36 non-null     int64
#  1   Age                       36 non-null     int64
#  2   Gender                    36 non-null     int64
#  3   Weight                    36 non-null     float64
#  4   Height                    36 non-null     float64
#  5   Race                      36 non-null     object
#  6   Diabetes Status           36 non-null     int64
#  7   A1C                       36 non-null     float64
#  8   Baseline Fasting Glucose  36 non-null     float64
#  9   Insulin                   36 non-null     float64
#  10  Triglycerides             36 non-null     float64
#  11  Cholesterol               36 non-null     float64
#  12  HDL                       36 non-null     float64
#  13  Non-HDL                   36 non-null     float64
#  14  LDL                       36 non-null     float64
#  15  VLDL                      36 non-null     float64
#  16  CHO/HDL Ratio             36 non-null     float64
#  17  HOMA-IR                   36 non-null     float64
#  18  BMI                       36 non-null     float64
#  19  Viome_0                   36 non-null     float64
#  20  Viome_1                   36 non-null     float64
#  21  Viome_2                   36 non-null     float64
#  22  Viome_3                   36 non-null     float64
#  23  Viome_4                   36 non-null     float64
#  24  Viome_5                   36 non-null     float64
#  25  Viome_6                   36 non-null     float64
#  26  Viome_7                   36 non-null     float64
#  27  Viome_8                   36 non-null     float64
#  28  Viome_9                   36 non-null     float64
#  29  Viome_10                  36 non-null     float64
#  30  Viome_11                  36 non-null     float64
#  31  Viome_12                  36 non-null     float64
#  32  Viome_13                  36 non-null     float64
#  33  Viome_14                  36 non-null     float64
#  34  Viome_15                  36 non-null     float64
#  35  Viome_16                  36 non-null     float64
#  36  Viome_17                  36 non-null     float64
#  37  Viome_18                  36 non-null     float64
#  38  Viome_19                  36 non-null     float64
#  39  Viome_20                  36 non-null     float64
#  40  Viome_21                  36 non-null     float64
#  41  Viome_22                  36 non-null     float64
#  42  Viome_23                  36 non-null     float64
#  43  Viome_24                  36 non-null     float64
#  44  Viome_25                  36 non-null     float64
#  45  Viome_26                  36 non-null     float64
# dtypes: float64(41), int64(4), object(1)
# memory usage: 13.1+ KB

# %%
label_train.head()
# Out:
#    Subject ID  Day  Breakfast Calories  Lunch Calories  Breakfast Carbs  \
# 0           1    2               448.0             830             66.0
# 1           1    3               608.0             435             66.0
# 2           1    4               712.0             555             66.0
# 3           1    5               902.0             355             73.0
# 4           1    6               268.0            1180             24.0
#
#    Lunch Carbs  Breakfast Fat  Lunch Fat  Breakfast Protein  Lunch Protein
# 0           92           10.5       42.0               22.0             17
# 1           16           10.5       14.0               66.0             66
# 2           94           42.0       13.0               22.0             12
# 3           19           42.0       15.0               66.0             32
# 4           81           10.5       54.5               22.0             88

# %%
label_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Subject ID          324 non-null    int64
#  1   Day                 324 non-null    int64
#  2   Breakfast Calories  324 non-null    float64
#  3   Lunch Calories      324 non-null    int64
#  4   Breakfast Carbs     324 non-null    float64
#  5   Lunch Carbs         324 non-null    int64
#  6   Breakfast Fat       324 non-null    float64
#  7   Lunch Fat           324 non-null    float64
#  8   Breakfast Protein   324 non-null    float64
#  9   Lunch Protein       324 non-null    int64
# dtypes: float64(5), int64(5)
# memory usage: 25.4 KB

# %%
combined_df = label_train.merge(df, on=['Subject ID'])

# %%
combined_df
# Out:
#      Subject ID  Day  Breakfast Calories  Lunch Calories  Breakfast Carbs  \
# 0             1    2               448.0             830             66.0
# 1             1    3               608.0             435             66.0
# 2             1    4               712.0             555             66.0
# 3             1    5               902.0             355             73.0
# 4             1    6               268.0            1180             24.0
# ..          ...  ...                 ...             ...              ...
# 319           7    6               268.0            1180             24.0
# 320           7    7               448.0             830             66.0
# 321           7    8               608.0             435             66.0
# 322           7    9               712.0             555             66.0
# 323           7   10               268.0             355             24.0
#
#      Lunch Carbs  Breakfast Fat  Lunch Fat  Breakfast Protein  Lunch Protein  \
# 0             92           10.5       42.0               22.0             17
# 1             16           10.5       14.0               66.0             66
# 2             94           42.0       13.0               22.0             12
# 3             19           42.0       15.0               66.0             32
# 4             81           10.5       54.5               22.0             88
# ..           ...            ...        ...                ...            ...
# 319           81           10.5       54.5               22.0             88
# 320           92           10.5       42.0               22.0             17
# 321           16           10.5       14.0               66.0             66
# 322           94           42.0       13.0               22.0             12
# 323           19           10.5       15.0               22.0             32
#
#      ...  Viome_17  Viome_18  Viome_19  Viome_20  Viome_21  Viome_22  \
# 0    ...  1.183266  0.123951  1.422716 -0.201777  0.773843 -0.125457
# 1    ...  1.183266  0.123951  1.422716 -0.201777  0.773843 -0.125457
# 2    ...  1.183266  0.123951  1.422716 -0.201777  0.773843 -0.125457
# 3    ...  1.183266  0.123951  1.422716 -0.201777  0.773843 -0.125457
# 4    ...  1.183266  0.123951  1.422716 -0.201777  0.773843 -0.125457
# ..   ...       ...       ...       ...       ...       ...       ...
# 319  ... -4.746553  2.002800  3.282698 -1.570438 -0.179446  0.263283
# 320  ... -4.746553  2.002800  3.282698 -1.570438 -0.179446  0.263283
# 321  ... -4.746553  2.002800  3.282698 -1.570438 -0.179446  0.263283
# 322  ... -4.746553  2.002800  3.282698 -1.570438 -0.179446  0.263283
# 323  ... -4.746553  2.002800  3.282698 -1.570438 -0.179446  0.263283
#
#      Viome_23  Viome_24  Viome_25  Viome_26
# 0   -0.352396 -0.241578 -0.135894 -0.164389
# 1   -0.352396 -0.241578 -0.135894 -0.164389
# 2   -0.352396 -0.241578 -0.135894 -0.164389
# 3   -0.352396 -0.241578 -0.135894 -0.164389
# 4   -0.352396 -0.241578 -0.135894 -0.164389
# ..        ...       ...       ...       ...
# 319  0.491576  0.502913 -0.141314 -0.414110
# 320  0.491576  0.502913 -0.141314 -0.414110
# 321  0.491576  0.502913 -0.141314 -0.414110
# 322  0.491576  0.502913 -0.141314 -0.414110
# 323  0.491576  0.502913 -0.141314 -0.414110
#
# [324 rows x 55 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 55 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject ID                324 non-null    int64
#  1   Day                       324 non-null    int64
#  2   Breakfast Calories        324 non-null    float64
#  3   Lunch Calories            324 non-null    int64
#  4   Breakfast Carbs           324 non-null    float64
#  5   Lunch Carbs               324 non-null    int64
#  6   Breakfast Fat             324 non-null    float64
#  7   Lunch Fat                 324 non-null    float64
#  8   Breakfast Protein         324 non-null    float64
#  9   Lunch Protein             324 non-null    int64
#  10  Age                       324 non-null    int64
#  11  Gender                    324 non-null    int64
#  12  Weight                    324 non-null    float64
#  13  Height                    324 non-null    float64
#  14  Race                      324 non-null    object
#  15  Diabetes Status           324 non-null    int64
#  16  A1C                       324 non-null    float64
#  17  Baseline Fasting Glucose  324 non-null    float64
#  18  Insulin                   324 non-null    float64
#  19  Triglycerides             324 non-null    float64
#  20  Cholesterol               324 non-null    float64
#  21  HDL                       324 non-null    float64
#  22  Non-HDL                   324 non-null    float64
#  23  LDL                       324 non-null    float64
#  24  VLDL                      324 non-null    float64
#  25  CHO/HDL Ratio             324 non-null    float64
#  26  HOMA-IR                   324 non-null    float64
#  27  BMI                       324 non-null    float64
#  28  Viome_0                   324 non-null    float64
#  29  Viome_1                   324 non-null    float64
#  30  Viome_2                   324 non-null    float64
#  31  Viome_3                   324 non-null    float64
#  32  Viome_4                   324 non-null    float64
#  33  Viome_5                   324 non-null    float64
#  34  Viome_6                   324 non-null    float64
#  35  Viome_7                   324 non-null    float64
#  36  Viome_8                   324 non-null    float64
#  37  Viome_9                   324 non-null    float64
#  38  Viome_10                  324 non-null    float64
#  39  Viome_11                  324 non-null    float64
#  40  Viome_12                  324 non-null    float64
#  41  Viome_13                  324 non-null    float64
#  42  Viome_14                  324 non-null    float64
#  43  Viome_15                  324 non-null    float64
#  44  Viome_16                  324 non-null    float64
#  45  Viome_17                  324 non-null    float64
#  46  Viome_18                  324 non-null    float64
#  47  Viome_19                  324 non-null    float64
#  48  Viome_20                  324 non-null    float64
#  49  Viome_21                  324 non-null    float64
#  50  Viome_22                  324 non-null    float64
#  51  Viome_23                  324 non-null    float64
#  52  Viome_24                  324 non-null    float64
#  53  Viome_25                  324 non-null    float64
#  54  Viome_26                  324 non-null    float64
# dtypes: float64(46), int64(8), object(1)
# memory usage: 139.3+ KB

# %%
# Define RMSRE metric
def rmsre(y_true, y_pred):
    return np.sqrt(np.mean(((y_true - y_pred) / y_true) ** 2))

# %%
features = combined_df.drop(
    columns=[
        "Lunch Calories", 
        "Lunch Carbs", 
        "Lunch Fat",
        "Lunch Protein"
        ])
target = combined_df["Lunch Calories"]

categorical_columns = [col for col in features.columns if combined_df[col].nunique() < 5]
numerical_columns = [col for col in features.columns if col not in categorical_columns + ["Lunch Calories"]]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', RobustScaler(), numerical_columns),
        ('cat', OneHotEncoder(), categorical_columns)
    ]
)

# %%
# Define models and parameters
models_with_params = {
    "Linear Regression": {
        "model": LinearRegression(),
        "params": {
            "model__fit_intercept": [True, False]
        }
    },
    "Random Forest": {
        "model": RandomForestRegressor(random_state=42),
        "params": {
            "model__n_estimators": [50, 100, 200],
            "model__max_depth": [None, 10, 20],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4]
        }
    },
    "XGBoost": {
        "model": xgb.XGBRegressor(random_state=42, objective="reg:squarederror"),
        "params": {
            "model__n_estimators": [50, 100, 200],
            "model__max_depth": [3, 6, 10],
            "model__learning_rate": [0.01, 0.1, 0.2],
            "model__subsample": [0.8, 1.0]
        }
    },
    "Neural Network (MLP)": {
        "model": MLPRegressor(random_state=42, max_iter=500),
        "params": {
            "model__hidden_layer_sizes": [(50,), (100,), (50, 50)],
            "model__activation": ["relu", "tanh"],
            "model__solver": ["adam", "sgd"],
            "model__learning_rate": ["constant", "adaptive"]
        }
    },
    "SVM (SVR)": {
        "model": SVR(),
        "params": {
            "model__kernel": ["linear", "rbf"],
            "model__C": [0.1, 1, 10],
            "model__gamma": ["scale", "auto"]
        }
    }
}

# %%
X_train, X_val, y_train, y_val = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
X_train.head()
# Out:
#      Subject ID  Day  Breakfast Calories  Breakfast Carbs  Breakfast Fat  \
# 73           11    3               608.0             66.0           10.5
# 181          28    3               608.0             66.0           10.5
# 17            2   10               268.0             24.0           10.5
# 24            3    8               608.0             66.0           10.5
# 146          20    4               712.0             66.0           42.0
#
#      Breakfast Protein  Age  Gender  Weight  Height  ...  Viome_17  Viome_18  \
# 73                66.0   34       0   186.2    67.0  ...  3.645839  1.610915
# 181               66.0   59       1   204.8    60.0  ...  0.384493  0.382582
# 17                22.0   49       1   169.2    62.0  ...  0.348451  1.591451
# 24                66.0   59       1   157.0    64.0  ... -0.202068 -1.578614
# 146               22.0   59       1   206.2    63.5  ...  0.442699 -0.566262
#
#      Viome_19  Viome_20  Viome_21  Viome_22  Viome_23  Viome_24  Viome_25  \
# 73  -0.743516 -0.985421 -0.695481  0.646043  0.100610  0.435668 -0.018749
# 181 -0.215523  0.576788 -1.114855 -2.276211  1.733990 -1.680511 -3.062497
# 17   0.748944 -0.017463  0.514344 -0.392209 -0.211173 -0.210122 -0.007723
# 24  -1.356888  0.143230 -1.742321  0.451295  0.304562 -0.049945  0.188032
# 146  0.688064 -0.504941  2.772566  4.859711  1.418702  0.041219  3.204060
#
#      Viome_26
# 73   0.159910
# 181 -2.021651
# 17  -0.090217
# 24  -0.039500
# 146 -1.529950
#
# [5 rows x 51 columns]

# %% [markdown]
# ## Initial Model

# %%
pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', LinearRegression())
    ])

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   ['Subject ID', 'Day',
#                                                    'Breakfast Calories', 'Age',
#                                                    'Weight', 'Height', 'A1C',
#                                                    'Baseline Fasting Glucose',
#                                                    'Insulin', 'Triglycerides',
#                                                    'Cholesterol', 'HDL',
#                                                    'Non-HDL', 'LDL', 'VLDL',
#                                                    'CHO/HDL Ratio', 'HOMA-IR',
#                                                    'BMI', 'Viome_0', 'Viome_1',
#                                                    'Viome_2', 'Viome_3',
#                                                    'Viome_4', 'Viome_5',
#                                                    'Viome_6', 'Viome_7',
#                                                    'Viome_8', 'Viome_9',
#                                                    'Viome_10', 'Viome_11', ...]),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['Breakfast Carbs',
#                                                    'Breakfast Fat',
#                                                    'Breakfast Protein',
#                                                    'Gender', 'Race',
#                                                    'Diabetes Status'])])),
#                 ('model', LinearRegression())])

# %% [markdown]
# ## Tuning

# %%
# Evaluate each model
results = []
best_model = None
best_model_name = None
lowest_rmsre = float('inf')

for model_name, model_info in models_with_params.items():
    print(f"***\nEvaluating model: {model_name}")
    # Define pipeline
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', model_info["model"])
    ])

    # Grid Search
    grid_search = GridSearchCV(
        pipeline, 
        model_info["params"], 
        cv=5, 
        scoring='neg_mean_squared_error', 
        n_jobs=-1,
        error_score='raise',
        verbose=1
    )
    try:
        grid_search.fit(X_train, y_train)

        # Best model predictions on test set
        best_cv_score = -grid_search.best_score_  # Convert back to positive MSE
        
        # Evaluate on the validation set
        y_val_pred = grid_search.best_estimator_.predict(X_val)
        val_mse = mean_squared_error(y_val, y_val_pred)
        val_mae = mean_absolute_error(y_val, y_val_pred)
        val_r2 = r2_score(y_val, y_val_pred)
        val_rmsre = rmsre(y_val, y_val_pred)

        # Store results
        result =  {
            "Model": model_name,
            "Best Parameters": grid_search.best_params_,
            "Mean CV MSE": best_cv_score,
            "Validation MSE": val_mse,
            "Validation MAE": val_mae,
            "Validation R2": val_r2,
            "Validation RMSRE": val_rmsre
        }
        if result["Validation RMSRE"] < lowest_rmsre:
            lowest_rmsre = result["Validation RMSRE"]
            best_model = grid_search.best_estimator_ 
            best_model_name = model_name

        results.append(result)

    except Exception as e:
        print(f"Error with model {model_name}: {e}")
        continue
# Out:
# ***
# Evaluating model: Linear Regression
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# ***
# Evaluating model: Random Forest
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# ***
# Evaluating model: XGBoost
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# ***
# Evaluating model: Neural Network (MLP)
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Error with model Neural Network (MLP): Solver produced non-finite parameter weights. The input data may contain large values and need to be preprocessed.
# ***
# Evaluating model: SVM (SVR)
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
comparison_df = pd.DataFrame(results).sort_values(by="Validation RMSRE")
comparison_df
# Out:
#                Model                                    Best Parameters  \
# 2            XGBoost  {'model__learning_rate': 0.1, 'model__max_dept...
# 1      Random Forest  {'model__max_depth': None, 'model__min_samples...
# 0  Linear Regression                     {'model__fit_intercept': True}
# 3          SVM (SVR)  {'model__C': 10, 'model__gamma': 'scale', 'mod...
#
#     Mean CV MSE  Validation MSE  Validation MAE  Validation R2  \
# 2   1640.273979        2.419001        1.274834       0.999963
# 1   1703.575185        3.374100        0.639359       0.999949
# 0  45492.345112    35828.791587      154.825962       0.455153
# 3  56482.673049    27233.784083       62.315038       0.585857
#
#    Validation RMSRE
# 2          0.002514
# 1          0.004639
# 0          0.334439
# 3          0.414375

# %%
best_model.get_params()['model']
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=50, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
demograph_test_df = viome_test.drop(columns = ["Viome"], axis = 1)
expanded_df_test = pd.DataFrame(
    viome_test['Viome'].to_list(), 
    columns=[f'Viome_{i}' for i in range(len(viome_test['Viome'][0]))])

# Combine with the original DataFrame (if needed)
df_test = pd.concat([demograph_test_df, expanded_df_test], axis=1)
combined_df_test = label_test.merge(df_test, on=['Subject ID'])

# %%
combined_df_test.head()
# Out:
#    Subject ID  Day  Breakfast Calories  Breakfast Carbs  Breakfast Fat  \
# 0           4    2               448.0             66.0           10.5
# 1           4    3               608.0             66.0           10.5
# 2           4    6               268.0             24.0           10.5
# 3           4    7               448.0             66.0           10.5
# 4           4    8               608.0             66.0           10.5
#
#    Breakfast Protein  Age  Gender  Weight  Height  ...  Viome_17  Viome_18  \
# 0               22.0   33       1   262.6    66.0  ... -2.225667  0.969485
# 1               66.0   33       1   262.6    66.0  ... -2.225667  0.969485
# 2               22.0   33       1   262.6    66.0  ... -2.225667  0.969485
# 3               22.0   33       1   262.6    66.0  ... -2.225667  0.969485
# 4               66.0   33       1   262.6    66.0  ... -2.225667  0.969485
#
#    Viome_19  Viome_20  Viome_21  Viome_22  Viome_23  Viome_24  Viome_25  \
# 0  0.612467 -0.263281  0.389482 -0.622622 -0.101613 -0.639292 -0.153909
# 1  0.612467 -0.263281  0.389482 -0.622622 -0.101613 -0.639292 -0.153909
# 2  0.612467 -0.263281  0.389482 -0.622622 -0.101613 -0.639292 -0.153909
# 3  0.612467 -0.263281  0.389482 -0.622622 -0.101613 -0.639292 -0.153909
# 4  0.612467 -0.263281  0.389482 -0.622622 -0.101613 -0.639292 -0.153909
#
#    Viome_26
# 0 -0.044839
# 1 -0.044839
# 2 -0.044839
# 3 -0.044839
# 4 -0.044839
#
# [5 rows x 51 columns]

# %%
# Train the best model on the entire training set (train + validation)
best_model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val]))

# Make predictions on the test set
y_test_pred = best_model.predict(combined_df_test)

# Display the best model and test predictions
print(f"Best Model: {best_model_name}")
print(f"Validation RMSRE: {lowest_rmsre}")
# Out:
# Best Model: XGBoost
# Validation RMSRE: 0.002514146379769567

# %%
y_test_pred_df = pd.DataFrame(y_test_pred, columns = ['label'])
y_test_pred_df.head()
# Out:
#          label
# 0   828.779846
# 1   435.993256
# 2  1176.599731
# 3   828.779846
# 4   435.993256

# %%
submissions = y_test_pred_df.to_csv("dirty_third_model.csv", index_label="row_id")
